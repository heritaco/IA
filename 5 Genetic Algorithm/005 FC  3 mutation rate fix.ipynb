# %%
"""FC3 Genetic Alorithm from El Rosario to Consulado"""

import random
from typing import List, Tuple


class Ruta:
    """Clase para representar una ruta entre dos puntos de la ciudad"""
    def __init__(self, a: str, b: str, time: int, linea: str):
        self.start = a
        self.end = b
        self.time = time
        self.linea = linea

    def __str__(self):
        return f'Ruta: de {self.start} a {self.end} (Linea {self.linea})'

estaciones = [
    "Atlalilco",          # 0
    "Balderas",           # 1
    "Barranca del Muerto",  # 2
    "Bellas Artes",       # 3
    "Candelaria",         # 4
    "Centro Médico",      # 5
    "Chabacano",          # 6
    "Ciudad Azteca",      # 7
    "Consulado",          # 8
    "Cuatro Caminos",     # 9
    "Deportivo 18 de Marzo",  # 10
    "El Rosario",         # 11
    "Ermita",             # 12
    "Garibaldi",          # 13
    "Gómez Farías",       # 14
    "Guerrero",           # 15
    "Hidalgo",            # 16
    "Indios Verdes",      # 17
    "Instituto del Petroleo",  # 18
    "Jamaica",            # 19
    "La Raza",            # 20
    "Martín Carrera",     # 21
    "Mixcoac",            # 22
    "Morelos",            # 23
    "Oceanía",            # 24
    "Pantitlán",          # 25
    "Pino Suárez",        # 26
    "Politécnico",        # 27
    "Salto del Agua",     # 28
    "San Lázaro",         # 29
    "Tacuba",             # 30
    "Tacubaya",           # 31
    "Tasqueña",           # 32
    "Tláhuac",            # 33
    "Universidad",        # 34
    "Zapata"              # 35
]


rutas = [
    Ruta(estaciones[3], estaciones[8], 1, '1'),
    Ruta(estaciones[2], estaciones[12], 10, '2'),
    Ruta(estaciones[2], estaciones[3], 1, '3'),
    Ruta(estaciones[2], estaciones[8], 100, '4'),
    Ruta(estaciones[1], estaciones[2], 1, '5'),
    Ruta(estaciones[11], estaciones[16], 10, '6'),
    Ruta(estaciones[16], estaciones[8], 3, '7'),
    Ruta(estaciones[18], estaciones[20], 1, '8'),
    Ruta(estaciones[20], estaciones[8], 1, '9'),
    Ruta(estaciones[20], estaciones[10], 3, '10'),
    Ruta(estaciones[8], estaciones[3], 1, '1'),
    Ruta(estaciones[12], estaciones[2], 10, '2'),
    Ruta(estaciones[3], estaciones[2], 1, '3'),
    Ruta(estaciones[8], estaciones[2], 100, '4'),
    Ruta(estaciones[2], estaciones[1], 1, '5'),
    Ruta(estaciones[16], estaciones[11], 10, '6'),
    Ruta(estaciones[8], estaciones[16], 3, '7'),
    Ruta(estaciones[20], estaciones[18], 1, '8'),
    Ruta(estaciones[8], estaciones[20], 1, '9'),
    Ruta(estaciones[10], estaciones[20], 3, '10')]

# %%
start_point = 'Balderas'
end_point = 'Consulado'
size_pop = 10
num_generations = 10
elite_size = 3
mutation_rate = 1
# Genome

# %%
Genome = Tuple[List[int], int, List[str], List[Tuple[str, str]]]
# List of indexes, time, lineas, stages

def generate_genome(rutas: List[Ruta], start_point: str, end_point: str) -> Genome:
    current_point = start_point
    indexes = []
    stages = []
    while current_point != end_point:
        available_routes = [i for i, ruta in enumerate(rutas) if current_point == ruta.start]
        if not available_routes:
            raise ValueError(f"No available routes from {current_point}")
        i = random.choice(available_routes)
        indexes.append(i)
        next_point = rutas[i].end
        stages.append((current_point, next_point))
        current_point = next_point
    time = sum(rutas[i].time for i in indexes)
    lineas = [rutas[i].linea for i in indexes]
    genome_str = f" El tiempo fue de: {time}, Rutas disponibles tomadas: {indexes}, Las estaciones fueron de: {stages}, en las lineas: {lineas},"
    return indexes, time, lineas, stages, genome_str

genome = generate_genome(rutas, start_point, end_point)
print(genome[4])
# Out:
#  El tiempo fue de: 103, Rutas disponibles tomadas: [4, 2, 12, 3], Las estaciones fueron de: [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Barranca del Muerto'), ('Barranca del Muerto', 'Consulado')], en las lineas: ['5', '3', '3', '4'],

# %%
# Population
Population = List[Genome]

def generate_population(rutas: List[Ruta], size_pop) -> Population:
    """function to generate a population of genomes"""
    return [generate_genome(rutas, start_point, end_point) for _ in range(size_pop)]

population = generate_population(rutas, size_pop)
print('\n'.join(map(str, population)))
# Out:
# ([4, 14, 4, 1, 11, 3], 123, ['5', '5', '5', '2', '2', '4'], [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Consulado')], " El tiempo fue de: 123, Rutas disponibles tomadas: [4, 14, 4, 1, 11, 3], Las estaciones fueron de: [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Consulado')], en las lineas: ['5', '5', '5', '2', '2', '4'],")
# ([4, 3], 101, ['5', '4'], [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Consulado')], " El tiempo fue de: 101, Rutas disponibles tomadas: [4, 3], Las estaciones fueron de: [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Consulado')], en las lineas: ['5', '4'],")
# ([4, 3], 101, ['5', '4'], [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Consulado')], " El tiempo fue de: 101, Rutas disponibles tomadas: [4, 3], Las estaciones fueron de: [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Consulado')], en las lineas: ['5', '4'],")
# ([4, 2, 0], 3, ['5', '3', '1'], [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Consulado')], " El tiempo fue de: 3, Rutas disponibles tomadas: [4, 2, 0], Las estaciones fueron de: [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Consulado')], en las lineas: ['5', '3', '1'],")
# ([4, 14, 4, 1, 11, 1, 11, 14, 4, 3], 145, ['5', '5', '5', '2', '2', '2', '2', '5', '5', '4'], [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Consulado')], " El tiempo fue de: 145, Rutas disponibles tomadas: [4, 14, 4, 1, 11, 1, 11, 14, 4, 3], Las estaciones fueron de: [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Consulado')], en las lineas: ['5', '5', '5', '2', '2', '2', '2', '5', '5', '4'],")
# ([4, 1, 11, 2, 0], 23, ['5', '2', '2', '3', '1'], [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Consulado')], " El tiempo fue de: 23, Rutas disponibles tomadas: [4, 1, 11, 2, 0], Las estaciones fueron de: [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Consulado')], en las lineas: ['5', '2', '2', '3', '1'],")
# ([4, 14, 4, 14, 4, 3], 105, ['5', '5', '5', '5', '5', '4'], [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Consulado')], " El tiempo fue de: 105, Rutas disponibles tomadas: [4, 14, 4, 14, 4, 3], Las estaciones fueron de: [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Consulado')], en las lineas: ['5', '5', '5', '5', '5', '4'],")
# ([4, 14, 4, 3], 103, ['5', '5', '5', '4'], [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Consulado')], " El tiempo fue de: 103, Rutas disponibles tomadas: [4, 14, 4, 3], Las estaciones fueron de: [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Consulado')], en las lineas: ['5', '5', '5', '4'],")
# ([4, 1, 11, 14, 4, 3], 123, ['5', '2', '2', '5', '5', '4'], [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Consulado')], " El tiempo fue de: 123, Rutas disponibles tomadas: [4, 1, 11, 14, 4, 3], Las estaciones fueron de: [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Consulado')], en las lineas: ['5', '2', '2', '5', '5', '4'],")
# ([4, 14, 4, 1, 11, 2, 12, 1, 11, 1, 11, 14, 4, 14, 4, 2, 0], 71, ['5', '5', '5', '2', '2', '3', '3', '2', '2', '2', '2', '5', '5', '5', '5', '3', '1'], [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Consulado')], " El tiempo fue de: 71, Rutas disponibles tomadas: [4, 14, 4, 1, 11, 2, 12, 1, 11, 1, 11, 14, 4, 14, 4, 2, 0], Las estaciones fueron de: [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Consulado')], en las lineas: ['5', '5', '5', '2', '2', '3', '3', '2', '2', '2', '2', '5', '5', '5', '5', '3', '1'],")

# %%
def fitness(genome: Genome, rutas: List[Ruta]) -> float:
    """function to calculate the fitness of a genome"""
    time = genome[1]  # genome[1] is the total time
    value = 1/time if time != 0 else 0  # Avoid division by zero
    return value

# %%
# Calculate fitness values for all genomes
fitness_values = [(genome, fitness(genome, rutas)) for genome in population]

# Sort by fitness value in descending order
sorted_by_fitness = sorted(fitness_values, key=lambda x: x[1], reverse=True)

# Get the 2 genomes with the highest fitness values
best_genomes = [genome for genome in sorted_by_fitness[:elite_size]]

print("\nFitness values:")
for i, genome in enumerate(population):
    print(fitness_values[i][1])

print("\nFitness values after sorting:")
for i, genome in enumerate(population):
    print(sorted_by_fitness[i][1])

print("\nBest genomes:")
for genome in best_genomes:
    print(genome)
# Out:
# Fitness values:
# 0.008130081300813009
# 0.009900990099009901
# 0.009900990099009901
# 0.3333333333333333
# 0.006896551724137931
# 0.043478260869565216
# 0.009523809523809525
# 0.009708737864077669
# 0.008130081300813009
# 0.014084507042253521
#
# Fitness values after sorting:
# 0.3333333333333333
# 0.043478260869565216
# 0.014084507042253521
# 0.009900990099009901
# 0.009900990099009901
# 0.009708737864077669
# 0.009523809523809525
# 0.008130081300813009
# 0.008130081300813009
# 0.006896551724137931
#
# Best genomes:
# (([4, 2, 0], 3, ['5', '3', '1'], [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Consulado')], " El tiempo fue de: 3, Rutas disponibles tomadas: [4, 2, 0], Las estaciones fueron de: [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Consulado')], en las lineas: ['5', '3', '1'],"), 0.3333333333333333)
# (([4, 1, 11, 2, 0], 23, ['5', '2', '2', '3', '1'], [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Consulado')], " El tiempo fue de: 23, Rutas disponibles tomadas: [4, 1, 11, 2, 0], Las estaciones fueron de: [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Consulado')], en las lineas: ['5', '2', '2', '3', '1'],"), 0.043478260869565216)
# (([4, 14, 4, 1, 11, 2, 12, 1, 11, 1, 11, 14, 4, 14, 4, 2, 0], 71, ['5', '5', '5', '2', '2', '3', '3', '2', '2', '2', '2', '5', '5', '5', '5', '3', '1'], [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Consulado')], " El tiempo fue de: 71, Rutas disponibles tomadas: [4, 14, 4, 1, 11, 2, 12, 1, 11, 1, 11, 14, 4, 14, 4, 2, 0], Las estaciones fueron de: [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Consulado')], en las lineas: ['5', '5', '5', '2', '2', '3', '3', '2', '2', '2', '2', '5', '5', '5', '5', '3', '1'],"), 0.014084507042253521)

# %%
def elitism(population: Population, rutas: List[Ruta], elite_size: int) -> Population:
    """function to carry over the top individuals to the next generation"""
    fitness_values = [(genome, fitness(genome, rutas)) for genome in population]
    sorted_by_fitness = sorted(fitness_values, key=lambda x: x[1], reverse=True)
    elite = [genome for genome in sorted_by_fitness[:elite_size]]
    return elite, fitness_values, sorted_by_fitness

elite, fitness_values, sorted_by_fitness = elitism(population, rutas, elite_size)

print("\nFitness values:")
for i, genome in enumerate(population):
    print(fitness_values[i][1])

print("\nFitness values afer sorting:")
for i, genome in enumerate(population):
    print(sorted_by_fitness[i][1])
# Out:
# Fitness values:
# 0.008130081300813009
# 0.009900990099009901
# 0.009900990099009901
# 0.3333333333333333
# 0.006896551724137931
# 0.043478260869565216
# 0.009523809523809525
# 0.009708737864077669
# 0.008130081300813009
# 0.014084507042253521
#
# Fitness values afer sorting:
# 0.3333333333333333
# 0.043478260869565216
# 0.014084507042253521
# 0.009900990099009901
# 0.009900990099009901
# 0.009708737864077669
# 0.009523809523809525
# 0.008130081300813009
# 0.008130081300813009
# 0.006896551724137931

# %% [markdown]
# No tengo idea como hacer el crossover, supongo que cuando haya un punto en comun, pero pueden tomar muchos muchos muchos caminos, mejor solo usamos elitismo

# %%
def flatten(lst):
    return [item for sublist in lst for item in sublist]

def mutate_genome(genome: Genome, rutas: List[Ruta], start_point: str, end_point: str) -> Genome:
    """function to mutate a genome"""
    # Flatten the list of indexes if it's a list of lists
    genome[0] = flatten(genome[0])
    # Choose a random index to mutate
    index_to_mutate = random.randint(1, len(genome[0]) - 1)
    new_start_point = rutas[genome[0][index_to_mutate - 1]].end  # Use the index directly
    # Generate a new route
    new_route = generate_genome(rutas, new_start_point, end_point)
    # Create the new genome
    new_genome = list(genome)
    new_genome[0] = new_genome[0][:index_to_mutate] + new_route[0]
    new_genome[1] = sum(rutas[i].time for i in new_genome[0])
    new_genome[2] = [rutas[i].linea for i in new_genome[0]]
    new_genome[3] = [(rutas[i].start, rutas[i].end) for i in new_genome[0]]
    new_genome[4] = f" El tiempo fue de: {new_genome[1]}, Rutas disponibles tomadas: {new_genome[0]}, Las estaciones fueron de: {new_genome[3]}, en las lineas: {new_genome[2]},"
    return tuple(new_genome)

# %%
def create_new_population(population: Population, rutas: List[Ruta], elite_size: int, mutation_rate: float, size_pop: int) -> Tuple[Population, int]:
    """function to create a new population and count the number of mutations"""
    # Select the elite individuals
    elite = elitism(population, rutas, elite_size)
    # Generate mutations of the elite individuals and count the number of mutations
    mutations = []
    mutation_count = 0
    for genome in elite:
        if random.random() < mutation_rate:
            mutations.append(mutate_genome(genome, rutas, start_point, end_point))
            mutation_count += 1
    # Generate random genomes
    random_genomes = [generate_genome(rutas, start_point, end_point) for _ in range(size_pop - len(elite) - len(mutations))]
    # Create the new population
    new_population = list(elite) + mutations + random_genomes
    return new_population, mutation_count

new_population, mutation_count = create_new_population(population, rutas, elite_size, mutation_rate, size_pop)
print(f"\nNumber of mutations: {mutation_count}")
print("\nNew population:")
for genome in new_population:
    print(genome)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 18
#      15     new_population = list(elite) + mutations + random_genomes
#      16     return new_population, mutation_count
# ---> 18 new_population, mutation_count = create_new_population(population, rutas, elite_size, mutation_rate, size_pop)
#      19 print(f"\nNumber of mutations: {mutation_count}")
#      20 print("\nNew population:")
#
# Cell In[59], line 10, in create_new_population(population, rutas, elite_size, mutation_rate, size_pop)
#       8 for genome in elite:
#       9     if random.random() < mutation_rate:
# ---> 10         mutations.append(mutate_genome(genome, rutas, start_point, end_point))
#      11         mutation_count += 1
#      12 # Generate random genomes
#
# Cell In[58], line 5, in mutate_genome(genome, rutas, start_point, end_point)
#       3 # Choose a random index to mutate
#       4 index_to_mutate = random.randint(1, len(genome[0]) - 1)
# ----> 5 new_start_point = rutas[genome[0][index_to_mutate - 1]].end  # Use the index directly
#       6 # Generate a new route
#       7 new_route = generate_genome(rutas, new_start_point, end_point)
#
# TypeError: list indices must be integers or slices, not tuple

# %%
def run_genetic_algorithm(rutas: List[Ruta], size_pop: int, num_generations: int, elite_size: int, mutation_rate: int, start_point: str, end_point: str) -> Population:
    """Run a genetic algorithm."""
    # Generate the initial population
    population = generate_population(rutas, size_pop)

    # Run the algorithm for the specified number of generations
    for _ in range(num_generations):
        # Use elitism to carry over the top individuals to the next generation
        elite, fitness_values, sorted_by_fitness = elitism(population, rutas, elite_size)
        new_population = elite

        # Use mutation to introduce variation
        for genome in population[elite_size:]:
            if random.random() < mutation_rate:
                new_genome = mutate_genome(genome, rutas, start_point, end_point)
                new_population.append(new_genome)
            else:
                new_population.append(genome)

        population = new_population

    return population

# %%
run_genetic_algorithm(rutas, size_pop, num_generations, elite_size, mutation_rate, start_point, end_point)
# Out:
# [((((((((([4, 14, 4, 2, 0],
#           5,
#           ['5', '5', '5', '3', '1'],
#           [('Balderas', 'Barranca del Muerto'),
#            ('Barranca del Muerto', 'Balderas'),
#            ('Balderas', 'Barranca del Muerto'),
#            ('Barranca del Muerto', 'Bellas Artes'),
#            ('Bellas Artes', 'Consulado')],
#           " El tiempo fue de: 5, Rutas disponibles tomadas: [4, 14, 4, 2, 0], Las estaciones fueron de: [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Consulado')], en las lineas: ['5', '5', '5', '3', '1'],"),
#          0.2),
#         5.0),
#        0.2),
#       5.0),
#      0.2),
#     5.0),
#    0.2),
#   5.0),
#  ((((((((((([4, 2, 0],
#             3,
#             ['5', '3', '1'],
#             [('Balderas', 'Barranca del Muerto'),
#              ('Barranca del Muerto', 'Bellas Artes'),
#              ('Bellas Artes', 'Consulado')],
#             " El tiempo fue de: 3, Rutas disponibles tomadas: [4, 2, 0], Las estaciones fueron de: [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Consulado')], en las lineas: ['5', '3', '1'],"),
#            0.3333333333333333),
#           3.0),
#          0.3333333333333333),
#         3.0),
#        0.3333333333333333),
#       3.0),
#      0.3333333333333333),
#     3.0),
#    0.3333333333333333),
#   3.0),
#  ((((((((([4, 2, 0],
#           3,
#           ['5', '3', '1'],
#           [('Balderas', 'Barranca del Muerto'),
#            ('Barranca del Muerto', 'Bellas Artes'),
#            ('Bellas Artes', 'Consulado')],
#           " El tiempo fue de: 3, Rutas disponibles tomadas: [4, 2, 0], Las estaciones fueron de: [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Consulado')], en las lineas: ['5', '3', '1'],"),
#          0.3333333333333333),
#         3.0),
#        0.3333333333333333),
#       3.0),
#      0.3333333333333333),
#     3.0),
#    0.3333333333333333),
#   3.0),
#  ([4, 3],
#   101,
#   ['5', '4'],
#   [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Consulado')],
#   " El tiempo fue de: 101, Rutas disponibles tomadas: [4, 3], Las estaciones fueron de: [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Consulado')], en las lineas: ['5', '4'],"),
#  ([4, 1, 11, 14, 4, 2, 0],
#   25,
#   ['5', '2', '2', '5', '5', '3', '1'],
#   [('Balderas', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Ermita'),
#    ('Ermita', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Balderas'),
#    ('Balderas', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Bellas Artes'),
#    ('Bellas Artes', 'Consulado')],
#   " El tiempo fue de: 25, Rutas disponibles tomadas: [4, 1, 11, 14, 4, 2, 0], Las estaciones fueron de: [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Consulado')], en las lineas: ['5', '2', '2', '5', '5', '3', '1'],"),
#  ([4,
#    1,
#    11,
#    2,
#    12,
#    1,
#    11,
#    1,
#    11,
#    1,
#    11,
#    14,
#    4,
#    14,
#    4,
#    14,
#    4,
#    2,
#    12,
#    14,
#    4,
#    14,
#    4,
#    2,
#    12,
#    1,
#    11,
#    2,
#    12,
#    2,
#    0],
#   121,
#   ['5',
#    '2',
#    '2',
#    '3',
#    '3',
#    '2',
#    '2',
#    '2',
#    '2',
#    '2',
#    '2',
#    '5',
#    '5',
#    '5',
#    '5',
#    '5',
#    '5',
#    '3',
#    '3',
#    '5',
#    '5',
#    '5',
#    '5',
#    '3',
#    '3',
#    '2',
#    '2',
#    '3',
#    '3',
#    '3',
#    '1'],
#   [('Balderas', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Ermita'),
#    ('Ermita', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Bellas Artes'),
#    ('Bellas Artes', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Ermita'),
#    ('Ermita', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Ermita'),
#    ('Ermita', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Ermita'),
#    ('Ermita', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Balderas'),
#    ('Balderas', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Balderas'),
#    ('Balderas', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Balderas'),
#    ('Balderas', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Bellas Artes'),
#    ('Bellas Artes', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Balderas'),
#    ('Balderas', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Balderas'),
#    ('Balderas', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Bellas Artes'),
#    ('Bellas Artes', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Ermita'),
#    ('Ermita', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Bellas Artes'),
#    ('Bellas Artes', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Bellas Artes'),
#    ('Bellas Artes', 'Consulado')],
#   " El tiempo fue de: 121, Rutas disponibles tomadas: [4, 1, 11, 2, 12, 1, 11, 1, 11, 1, 11, 14, 4, 14, 4, 14, 4, 2, 12, 14, 4, 14, 4, 2, 12, 1, 11, 2, 12, 2, 0], Las estaciones fueron de: [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Consulado')], en las lineas: ['5', '2', '2', '3', '3', '2', '2', '2', '2', '2', '2', '5', '5', '5', '5', '5', '5', '3', '3', '5', '5', '5', '5', '3', '3', '2', '2', '3', '3', '3', '1'],"),
#  ([4, 14, 4, 3],
#   103,
#   ['5', '5', '5', '4'],
#   [('Balderas', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Balderas'),
#    ('Balderas', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Consulado')],
#   " El tiempo fue de: 103, Rutas disponibles tomadas: [4, 14, 4, 3], Las estaciones fueron de: [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Consulado')], en las lineas: ['5', '5', '5', '4'],"),
#  ([4, 1, 11, 2, 12, 14, 4, 2, 12, 3],
#   127,
#   ['5', '2', '2', '3', '3', '5', '5', '3', '3', '4'],
#   [('Balderas', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Ermita'),
#    ('Ermita', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Bellas Artes'),
#    ('Bellas Artes', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Balderas'),
#    ('Balderas', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Bellas Artes'),
#    ('Bellas Artes', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Consulado')],
#   " El tiempo fue de: 127, Rutas disponibles tomadas: [4, 1, 11, 2, 12, 14, 4, 2, 12, 3], Las estaciones fueron de: [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Ermita'), ('Ermita', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Barranca del Muerto'), ('Barranca del Muerto', 'Consulado')], en las lineas: ['5', '2', '2', '3', '3', '5', '5', '3', '3', '4'],"),
#  ([4, 14, 4, 2, 12, 2, 0],
#   7,
#   ['5', '5', '5', '3', '3', '3', '1'],
#   [('Balderas', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Balderas'),
#    ('Balderas', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Bellas Artes'),
#    ('Bellas Artes', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Bellas Artes'),
#    ('Bellas Artes', 'Consulado')],
#   " El tiempo fue de: 7, Rutas disponibles tomadas: [4, 14, 4, 2, 12, 2, 0], Las estaciones fueron de: [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Consulado')], en las lineas: ['5', '5', '5', '3', '3', '3', '1'],"),
#  ([4, 14, 4, 14, 4, 2, 0],
#   7,
#   ['5', '5', '5', '5', '5', '3', '1'],
#   [('Balderas', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Balderas'),
#    ('Balderas', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Balderas'),
#    ('Balderas', 'Barranca del Muerto'),
#    ('Barranca del Muerto', 'Bellas Artes'),
#    ('Bellas Artes', 'Consulado')],
#   " El tiempo fue de: 7, Rutas disponibles tomadas: [4, 14, 4, 14, 4, 2, 0], Las estaciones fueron de: [('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Balderas'), ('Balderas', 'Barranca del Muerto'), ('Barranca del Muerto', 'Bellas Artes'), ('Bellas Artes', 'Consulado')], en las lineas: ['5', '5', '5', '5', '5', '3', '1'],")]

# %%
def genetic_algorithm(rutas: List[Ruta], population: Population, num_generations: int, elite_size: int, mutation_rate: float):
    """function to run the genetic algorithm"""
    for _ in range(num_generations):
        # Carry over the elite individuals to the next generation
        elite, fitness_values, sorted_by_fitness = elitism(population, rutas, elite_size)
        new_population = elite

        # Mutate the elite individuals
        for genome in elite:
            if random.random() < mutation_rate:
                mutated_genome = mutate_genome(genome, rutas, start_point, end_point)
                new_population.append(mutated_genome)

        # If the population size decreases due to mutation, add new random genomes
        while len(new_population) < len(population):
            new_population.append(generate_genome(rutas, start_point, end_point))

        population = new_population

    # Return the final population and the fitness values of the last generation
    return population, fitness_values

# Run the genetic algorithm
final_population, final_fitness_values = genetic_algorithm(rutas, population, num_generations, elite_size, mutation_rate)

# Print the best genome from the final population
best_genome = max(final_population, key=lambda genome: fitness(genome, rutas))
print(f"Best genome: {best_genome}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 24
#      21     return population, fitness_values
#      23 # Run the genetic algorithm
# ---> 24 final_population, final_fitness_values = genetic_algorithm(rutas, population, num_generations, elite_size, mutation_rate)
#      26 # Print the best genome from the final population
#      27 best_genome = max(final_population, key=lambda genome: fitness(genome, rutas))
#
# Cell In[77], line 11, in genetic_algorithm(rutas, population, num_generations, elite_size, mutation_rate)
#       9 for genome in elite:
#      10     if random.random() < mutation_rate:
# ---> 11         mutated_genome = mutate_genome(genome, rutas, start_point, end_point)
#      12         new_population.append(mutated_genome)
#      14 # If the population size decreases due to mutation, add new random genomes
#
# Cell In[64], line 7, in mutate_genome(genome, rutas, start_point, end_point)
#       5 """function to mutate a genome"""
#       6 # Flatten the list of indexes if it's a list of lists
# ----> 7 genome[0] = flatten(genome[0])
#       8 # Choose a random index to mutate
#       9 index_to_mutate = random.randint(1, len(genome[0]) - 1)
#
# Cell In[64], line 2, in flatten(lst)
#       1 def flatten(lst):
# ----> 2     return [item for sublist in lst for item in sublist]
#
# TypeError: 'int' object is not iterable
